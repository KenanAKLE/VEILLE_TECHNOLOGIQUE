# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn as sns
import joblib
import openai

print("Toutes les librairies sont OK 🚀")
# Out:
# Toutes les librairies sont OK 🚀
